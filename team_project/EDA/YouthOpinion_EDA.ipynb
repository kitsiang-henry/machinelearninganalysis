# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("youth_opinions_3.csv")
smucolors = ["#151C55","#8A704C"]

for col in df:
    #get dtype for column
    dt = df[col].dtype 
    #check if it is a number
    if dt == int or dt == float:
        df[col] = df[col].fillna(0)
    else:
        df[col] = df[col].fillna("-")
        
df.shape
# Out:
# (74, 20)

# %%
df.sample(20)
# Out:
#     Gender                 Faculty/School  \
# 46    Male  School of Information Systems
# 71    Male  School of Information Systems
# 50  Female      School of Social Sciences
# 12  Female             School of Business
# 10    Male  School of Information Systems
# 43    Male  School of Information Systems
# 33    Male  School of Information Systems
# 15  Female  School of Information Systems
# 18  Female  School of Information Systems
# 14  Female  School of Information Systems
# 64    Male  School of Information Systems
# 24  Female             School of Business
# 60  Female      School of Social Sciences
# 63  Female                  School of Law
# 1   Female      School of Social Sciences
# 9     Male  School of Information Systems
# 42    Male            School of Economics
# 41  Female      School of Social Sciences
# 39  Female  School of Information Systems
# 54  Female             School of Business
#
#    Are you an Undergraduate or a Postgraduate?    Year  \
# 46                               Undergraduate  Year 3
# 71                               Undergraduate  Year 4
# 50                               Undergraduate  Year 2
# 12                               Undergraduate  Year 4
# 10                               Undergraduate  Year 4
# 43                               Undergraduate  Year 3
# 33                               Undergraduate  Year 4
# 15                               Undergraduate  Year 3
# 18                               Undergraduate  Year 1
# 14                               Undergraduate  Year 2
# 64                               Undergraduate  Year 3
# 24                               Undergraduate  Year 1
# 60                               Undergraduate  Year 3
# 63                               Undergraduate  Year 4
# 1                                Undergraduate  Year 2
# 9                                Undergraduate  Year 1
# 42                               Undergraduate  Year 4
# 41                               Undergraduate  Year 4
# 39                               Undergraduate  Year 2
# 54                               Undergraduate  Year 2
#
#    Have you cleared your Community Service Programme (CSP)  requirement?  \
# 46                                                Yes
# 71                                                Yes
# 50                                                 No
# 12                                                Yes
# 10                                                Yes
# 43                                                Yes
# 33                                                Yes
# 15                                                Yes
# 18                                                 No
# 14                                                Yes
# 64                                                Yes
# 24                                                 No
# 60                                                 No
# 63                                                Yes
# 1                                                 Yes
# 9                                                  No
# 42                                                Yes
# 41                                                 No
# 39                                                Yes
# 54                                                Yes
#
#    How did you clear your CSP requirement? Please give a short description.  \
# 46                                Rotaract & CSP camp
# 71  StarringSMU participant, StarringSMU facilitator
# 50                                                  -
# 12                                      Overseas Trip
# 10                                        School csp
# 43  Red Cross camp and activity, included blood do...
# 33                                     OCSP in year 2
# 15                                Project Illuminate
# 18                                                  -
# 14                                               OSCP
# 64                                          Heartcode
# 24                                                  -
# 60                                                  -
# 63                              Inspirar and starring
# 1                           Local CSP with Caretalyst
# 9                                                   -
# 42    I joined a local csp cca known as rotaract club
# 41                                                  -
# 39  With my CCA, we had this mini project that all...
# 54                                          Uni-y FOL
#
#    How are you planning to clear your CSP requirement?  \
# 46                                                  -
# 71                                                  -
# 50                                Through my CSP CCA
# 12                                                  -
# 10                                                  -
# 43                                                  -
# 33                                                  -
# 15                                                  -
# 18                                        no idea :')
# 14                                                  -
# 64                                                  -
# 24                                               OCSP
# 60  I'm left with 8h and I have cleared in part wi...
# 63                                                  -
# 1                                                   -
# 9                                      find local csp
# 42                                                  -
# 41          Volunteering weekly with Kitten Sanctuary
# 39                                                  -
# 54                                                  -
#
#     Do you often see elderly in SMU or around SMU?Rate from 1 to 4 where 1 - Not at all and 4 - Very often - Frequency of seeing elderly in SMU or around SMU  \
# 46                                                  2
# 71                                                  3
# 50                                                  3
# 12                                                  2
# 10                                                  3
# 43                                                  3
# 33                                                  2
# 15                                                  2
# 18                                                  3
# 14                                                  3
# 64                                                  2
# 24                                                  3
# 60                                                  4
# 63                                                  2
# 1                                                   2
# 9                                                   2
# 42                                                  2
# 41                                                  2
# 39                                                  3
# 54                                                  2
#
#    From your observation, what do the elderly usually do in SMU or around SMU?  \
# 46                                                  -
# 71                          Facilitate in cleanliness
# 50  employees of smu - drink & food stall auntie, ...
# 12                                                  -
# 10                                       As cleaners
# 43                       Sit down at Koufu for a chat
# 33                                                  -
# 15                                                  -
# 18  some are not elderly but within the age range ...
# 14                                           Cleaners
# 64                                                  -
# 24                                              Koufu
# 60  Lie on the benches or chairs and sleep; charge...
# 63                                                  -
# 1                                                   -
# 9                                                   -
# 42                                                  -
# 41                                                  -
# 39       They are working to keep SMU clean and safe
# 54                                                  -
#
#    Do you know that there are many elderly living near SMU such as Bras Basah Complex and Waterloo area?  \
# 46                                                 No
# 71                                                 No
# 50                                                 No
# 12                                                Yes
# 10                                                Yes
# 43                                                 No
# 33                                                 No
# 15                                                Yes
# 18                                                Yes
# 14                                                 No
# 64                                                Yes
# 24                                                Yes
# 60                                                Yes
# 63                                                 No
# 1                                                  No
# 9                                                  No
# 42                                                 No
# 41                                                Yes
# 39                                                 No
# 54                                                Yes
#
#     Other than your grandparents, how often do you interact with the elderly?Rate from 1 to 4 where 1 - Not at all and 4 - Very often - Frequency of interacting with elderly  \
# 46                                                  1
# 71                                                  2
# 50                                                  3
# 12                                                  2
# 10                                                  1
# 43                                                  1
# 33                                                  2
# 15                                                  2
# 18                                                  1
# 14                                                  1
# 64                                                  1
# 24                                                  2
# 60                                                  1
# 63                                                  1
# 1                                                   1
# 9                                                   1
# 42                                                  2
# 41                                                  1
# 39                                                  3
# 54                                                  2
#
#    Do you face any difficulties interacting with elderly?  \
# 46                                                Yes
# 71                                                 No
# 50                                                Yes
# 12                                                Yes
# 10                                                 No
# 43                                                 No
# 33                                                Yes
# 15                                                 No
# 18                                                Yes
# 14                                                 No
# 64                                                 No
# 24                                                 No
# 60                                                 No
# 63                                                 No
# 1                                                  No
# 9                                                 Yes
# 42                                                Yes
# 41                                                Yes
# 39                                                Yes
# 54                                                Yes
#
#                        What difficulties do you face?  \
# 46                                      communication
# 71                                                  -
# 50                                   Language barrier
# 12  Language barrier; one word answers when I star...
# 10                                                  -
# 43                                                  -
# 33                                   Language barrier
# 15                                                  -
# 18  they often speak dialect which i cannot unders...
# 14                                                  -
# 64                                                  -
# 24                                                  -
# 60                                                  -
# 63                                                  -
# 1                                                   -
# 9                                         no patience
# 42                  Language barriers, generation gap
# 41  Language barrier, culture barrier also as I fe...
# 39   Language barrier, just like volume wise and all
# 54           Language barrier (they speak in dialect)
#
#    Are you interested to participate in a local CSP at elderly centres?  \
# 46                                                 No
# 71                                                Yes
# 50                                                Yes
# 12                                                Yes
# 10                                                Yes
# 43                                                 No
# 33                                                Yes
# 15                                                Yes
# 18                                                Yes
# 14                                                 No
# 64                                                 No
# 24                                                 No
# 60                                                 No
# 63                                                Yes
# 1                                                 Yes
# 9                                                  No
# 42                                                Yes
# 41                                                 No
# 39                                                 No
# 54                                                Yes
#
#    What do you think about developing SMU and the area around it as an Intergenerational Hub?\nOur Vision of Intergenerational Hub: Elderly coming to SMU and facilities are available to promote healthy and active ageing as well as promote intergenerational interaction between elderly and youth.  \
# 46                                            No way!
# 71                                       That's good!
# 50                                            Not bad
# 12                          That's an excellent idea!
# 10                                            Not bad
# 43                                            Not bad
# 33                                       That's good!
# 15                          That's an excellent idea!
# 18                                            Not bad
# 14                                       That's good!
# 64                                            Not bad
# 24                    Don't really feel good about it
# 60                                       That's good!
# 63                          That's an excellent idea!
# 1                     Don't really feel good about it
# 9                     Don't really feel good about it
# 42                                       That's good!
# 41                                            Not bad
# 39                                            Not bad
# 54                          That's an excellent idea!
#
#    Please elaborate for your choice in the previous question.  \
# 46  it is more convenient for them if the promotio...
# 71  Ability to bridge the gap between the elderly ...
# 50  Open to the idea just not sure whether SMU can...
# 12  students won’t have the excuse of saying that ...
# 10                                 Don't see why not
# 43  There may be clashes between the views of elde...
# 33  Given Singapore's ageing population, I think t...
# 15  Increase interaction and learn more about elde...
# 18  I am not so sure about an intergenerational hu...
# 14            I am like the idea of multiple land use
# 64  Im kinda apathetic but if it helps them thats ...
# 24  Don’t make elderly people move around. Younger...
# 60  Considering that there are other elderly-relat...
# 63  Since there's so many elderly nearby, it is go...
# 1   Feels like it might slow down the pace of scho...
# 9   they are gonna hog Koufu even more. and depend...
# 42  most elderly seldom come to town area, this ma...
# 41  SMU should primarily focus on improving educat...
# 39  Not much opinion tbh I’m cool with anything so...
# 54  It is a good idea as it minimises the distance...
#
#    What benefits do you think SMU will get for branding itself as an Intergenerational Hub for youth and the elderly?  \
# 46                                               nope
# 71                                 Holistic education
# 50                                         More open?
# 12  Society will definitely have a better impressi...
# 10                                           Not sure
# 43                               Boost reputation lol
# 33  It will definitely put us ahead of the other u...
# 15  Reaching out to the elderly will enable the sc...
# 18  hm, depends? either smu as an academic institu...
# 14                               Socially responsible
# 64  SMU can be the Singapore's first again just li...
# 24                                         Reputation
# 60  Err i guess publicity? And vibrancy also to no...
# 63                             Character development
# 1                                    Inclusive school
# 9   nothing much tbh. at most just get praised by ...
# 42      Promote cohesion between students and elderly
# 41  Maybe receive commendation by the public and m...
# 39                    More cap opportunities fOR SURE
# 54  More grants by the government to spearhead mor...
#
#    Do you think this Intergenerational Hub initiative will disrupt students' daily lives?  \
# 46                                                 No
# 71                                                 No
# 50                                                 No
# 12                                                 No
# 10                                                 No
# 43                                                Yes
# 33                                                 No
# 15                                                Yes
# 18                                                Yes
# 14                                                Yes
# 64                                                 No
# 24                                                 No
# 60                                                 No
# 63                                                 No
# 1                                                  No
# 9                                                 Yes
# 42                                                 No
# 41                                                Yes
# 39                                                Yes
# 54                                                 No
#
#    Please elaborate for your choice in the previous question..1  \
# 46                      students are unlikely to care
# 71  Out of class time, students may choose to pay ...
# 50                     I don't foresee any disruption
# 12           we have breaks in between classes anyway
# 10                           There's plenty of space
# 43  It will if it brings about negative changes be...
# 33  The hub will only provide the platform and ave...
# 15                  More movements around the school.
# 18  actually, this entirely depends on what you ai...
# 14  More crowds eg at eateries esp during lunch, t...
# 64                    I can choose not to do anything
# 24                                        Dontthinkso
# 60  It's still a choice for students to take part ...
# 63      It will help them grow instead of disrupting
# 1                      It does not matter to students
# 9                       cause more crowds and traffic
# 42  As long as this policy is well organised, i th...
# 41  Not enough details to imagine what sort of act...
# 39  Possibly, depending on where this hub is locat...
# 54  Students can do this as a CSP, does not affect...
#
#     Are you interested to participate in local CSPs which are to be conducted in SMU or around SMU?Rate from 1 to 4 where 1 - Not at all and 4 - Very interested - Interest level
# 46                                                  1
# 71                                                  3
# 50                                                  3
# 12                                                  4
# 10                                                  2
# 43                                                  2
# 33                                                  3
# 15                                                  3
# 18                                                  3
# 14                                                  1
# 64                                                  4
# 24                                                  1
# 60                                                  3
# 63                                                  4
# 1                                                   3
# 9                                                   1
# 42                                                  3
# 41                                                  2
# 39                                                  2
# 54                                                  1

# %%
df.columns
# Out:
# Index(['Gender', 'Faculty/School',
#        'Are you an Undergraduate or a Postgraduate?', 'Year',
#        'Have you cleared your Community Service Programme (CSP)  requirement?',
#        'How did you clear your CSP requirement? Please give a short description.',
#        'How are you planning to clear your CSP requirement?',
#        'Do you often see elderly in SMU or around SMU?Rate from 1 to 4 where 1 - Not at all and 4 - Very often - Frequency of seeing elderly in SMU or around SMU',
#        'From your observation, what do the elderly usually do in SMU or around SMU?',
#        'Do you know that there are many elderly living near SMU such as Bras Basah Complex and Waterloo area?',
#        'Other than your grandparents, how often do you interact with the elderly?Rate from 1 to 4 where 1 - Not at all and 4 - Very often - Frequency of interacting with elderly',
#        'Do you face any difficulties interacting with elderly?',
#        'What difficulties do you face?',
#        'Are you interested to participate in a local CSP at elderly centres?',
#        'What do you think about developing SMU and the area around it as an Intergenerational Hub?\nOur Vision of Intergenerational Hub: Elderly coming to SMU and facilities are available to promote healthy and active ageing as well as promote intergenerational interaction between elderly and youth.',
#        'Please elaborate for your choice in the previous question.',
#        'What benefits do you think SMU will get for branding itself as an Intergenerational Hub for youth and the elderly?',
#        'Do you think this Intergenerational Hub initiative will disrupt students' daily lives?',
#        'Please elaborate for your choice in the previous question..1',
#        'Are you interested to participate in local CSPs which are to be conducted in SMU or around SMU?Rate from 1 to 4 where 1 - Not at all and 4 - Very interested - Interest level'],
#       dtype='object')

# %%
#renamed columns

df.columns = ['gender','faculty','ug_pg','year','csp_cleared','cleared_mode',
              'clearing_plan','freq_see_elderly','elderly_do','knowledge_elderly_pop','freq_interact_w_elderly',
              'difficulties_interacting','difficulties_face','interest_participate_elderly_center_csp','thoughts_inter_hub','thoughts','brand',
              'disrupt_student_lives','disrupt_reason','interest_csp_elderly_smu']

df['csp_cleared'] = (df['csp_cleared'] == 'Yes' ).astype(int)
print(df['csp_cleared'].value_counts())


df['knowledge_elderly_pop'] = (df['knowledge_elderly_pop'] == 'Yes' ).astype(int)
print(df['knowledge_elderly_pop'].value_counts())

df['difficulties_interacting'] = (df['difficulties_interacting'] == 'Yes' ).astype(int)
print(df['difficulties_interacting'].value_counts())

df['interest_participate_elderly_center_csp'] = (df['interest_participate_elderly_center_csp'] == 'Yes' ).astype(int)
print(df['interest_participate_elderly_center_csp'].value_counts())
# Out:
# 1    42
# 0    32
# Name: csp_cleared, dtype: int64
# 0    43
# 1    31
# Name: knowledge_elderly_pop, dtype: int64
# 0    41
# 1    33
# Name: difficulties_interacting, dtype: int64
# 1    48
# 0    26
# Name: interest_participate_elderly_center_csp, dtype: int64

# %%
inter_hub_order = ["That's an excellent idea!","That's good!","Not bad","Don't really feel good about it","No way!"]
g = sns.FacetGrid(df,col="disrupt_student_lives",aspect=2.8,height=3,col_wrap=1)
g.map(sns.countplot,"thoughts_inter_hub",order=inter_hub_order,color="#151C55")
g.set_axis_labels("Thoughts of Intergenerational Hub", "thoughts_inter_hub");

# %%
#Encode the thoughts on intergenerational hub
def encode_score(data):
    if data == "That's an excellent idea!":
        return 4
    if data == "That's good!":
        return 3
    if data == "Not bad":
        return 2
    if data == "Don't really feel good about it":
        return 1
    if data == "No way!":
        return 0
    
def encode_gender(data):
    if data == "Male":
        return 1
    if data == "Female":
        return 0


df['disrupt_student_lives'] = (df['disrupt_student_lives'] == 'Yes' ).astype(int)
print(df['disrupt_student_lives'].value_counts())

    
df["gender"] = df["gender"].apply(encode_gender)
df["gender"] = df["gender"].astype(int)
df['thoughts_inter_hub'] = df['thoughts_inter_hub'].apply(encode_score)
df['thoughts_inter_hub'] = df['thoughts_inter_hub'].astype(int)
# Out:
# 0    56
# 1    18
# Name: disrupt_student_lives, dtype: int64

# %%
df["faculty"].value_counts()
# Out:
# School of Information Systems    38
# School of Business               18
# School of Social Sciences         9
# School of Accountancy             7
# School of Law                     1
# School of Economics               1
# Name: faculty, dtype: int64

# %%
smucolors = ["#151C55","#8A704C"]

plt.figure(figsize=(17,4))

sns.countplot(df["faculty"],palette=smucolors)

# %%
df.dtypes
# Out:
# gender                                      int64
# faculty                                    object
# ug_pg                                      object
# year                                       object
# csp_cleared                                 int64
# cleared_mode                               object
# clearing_plan                              object
# freq_see_elderly                            int64
# elderly_do                                 object
# knowledge_elderly_pop                       int64
# freq_interact_w_elderly                     int64
# difficulties_interacting                    int64
# difficulties_face                          object
# interest_participate_elderly_center_csp     int64
# thoughts_inter_hub                          int64
# thoughts                                   object
# brand                                      object
# disrupt_student_lives                       int64
# disrupt_reason                             object
# interest_csp_elderly_smu                    int64
# dtype: object

# %%
elderly_related = df["cleared_mode"]+ df["clearing_plan"]

words_related = "elderly|Inspirar|old folks"

elderly_related_count = elderly_related.str.contains(words_related).value_counts()[True]
print("Number of students who did/plans to do elderly related CSP: ",elderly_related_count)
print("Percentage/Probability of doing elderly related csp: ",elderly_related_count/len(elderly_related) * 100,'%')

might_be_words_related = "Uni-Y|uniy|uni-y|rotaract|Rotaract"

count = elderly_related.str.contains(might_be_words_related).value_counts()[True]
print("Number of students who might have done or plan to do elderly related CSP: ",count)
print("Percentage/Probability who might have done or plan to do elderly related csp: ",count/len(elderly_related) * 100,'%')

def score_csp_elderly(data):
    words_related = ["elderly","Inspirar","old","folks"]
    might_be_words_related = ["Uni-Y","uniy","uni-y","rotaract","Rotaract"]
    if any(word in data for word in words_related):
        return 2
    elif any(word in data for word in might_be_words_related):
        return 1
    return 0

df["csp_elderly_related"] = elderly_related.apply(score_csp_elderly)
#df["csp_is_elderly_related"]

df.dtypes
# Out:
# Number of students who did/plans to do elderly related CSP:  8
# Percentage/Probability of doing elderly related csp:  10.81081081081081 %
# Number of students who might have done or plan to do elderly related CSP:  6
# Percentage/Probability who might have done or plan to do elderly related csp:  8.108108108108109 %
# gender                                      int64
# faculty                                    object
# ug_pg                                      object
# year                                       object
# csp_cleared                                 int64
# cleared_mode                               object
# clearing_plan                              object
# freq_see_elderly                            int64
# elderly_do                                 object
# knowledge_elderly_pop                       int64
# freq_interact_w_elderly                     int64
# difficulties_interacting                    int64
# difficulties_face                          object
# interest_participate_elderly_center_csp     int64
# thoughts_inter_hub                          int64
# thoughts                                   object
# brand                                      object
# disrupt_student_lives                       int64
# disrupt_reason                             object
# interest_csp_elderly_smu                    int64
# csp_elderly_related                         int64
# dtype: object

# %%
plt.figure(figsize=[5,15])
csp_cleared_df = df.loc[df["year"] != "-"]
csp_cleared_df["year"].value_counts() #exclude post grad students since they not required to do it

with sns.plotting_context("notebook",font_scale=1.5):
    sns.catplot(data=csp_cleared_df,x="csp_cleared",kind="count",col="year",col_order=["Year 1","Year 2", "Year 3", "Year 4"],palette=smucolors)

# %%
len(csp_cleared_df.loc[csp_cleared_df["csp_cleared"]==0])
# Out:
# 31

# %%
#See distribution of data
df.hist(bins=5, figsize=(20, 10), layout=(3, 4));

# %%
def remove_year_text(data):
    if data == "-":
        return 0
    data = data.replace("Year","")
    data = int(data)
    return data

df["year"] = df["year"].apply(remove_year_text)
df["year"] = df["year"].astype(int)

# %%
df.sample(5)
# Out:
#     gender                        faculty          ug_pg  year  csp_cleared  \
# 3        0  School of Information Systems  Undergraduate     2            1
# 59       1      School of Social Sciences  Undergraduate     4            1
# 30       0             School of Business  Undergraduate     2            1
# 9        1  School of Information Systems  Undergraduate     1            0
# 33       1  School of Information Systems  Undergraduate     4            1
#
#                     cleared_mode   clearing_plan  freq_see_elderly elderly_do  \
# 3               Project with PSR               -                 1          -
# 59      CSP Camp, School Project               -                 2          -
# 30  With Red Cross volunteering                -                 2          -
# 9                              -  find local csp                 2          -
# 33                OCSP in year 2               -                 2          -
#
#     knowledge_elderly_pop  ...  difficulties_interacting  difficulties_face  \
# 3                       1  ...                         0                  -
# 59                      1  ...                         0                  -
# 30                      1  ...                         0                  -
# 9                       0  ...                         1        no patience
# 33                      0  ...                         1   Language barrier
#
#    interest_participate_elderly_center_csp  thoughts_inter_hub  \
# 3                                        0                   3
# 59                                       0                   3
# 30                                       0                   2
# 9                                        0                   1
# 33                                       1                   3
#
#                                              thoughts  \
# 3                  No time as busy with a project now
# 59  Had always believed that intergenerational ini...
# 30  It’s good especially when there is a rise in n...
# 9   they are gonna hog Koufu even more. and depend...
# 33  Given Singapore's ageing population, I think t...
#
#                                                 brand disrupt_student_lives  \
# 3                                  Multi-generational                     0
# 59  Unique value proposition as a university. Seen...                     1
# 30  Greater recognition for holistic development o...                     0
# 9   nothing much tbh. at most just get praised by ...                     1
# 33  It will definitely put us ahead of the other u...                     0
#
#                                        disrupt_reason  \
# 3      Theres nothing bad with building relationships
# 59  Only in terms of facilities utilisation as SMU...
# 30  Because this initiative can be done on a volun...
# 9                       cause more crowds and traffic
# 33  The hub will only provide the platform and ave...
#
#    interest_csp_elderly_smu  csp_elderly_related
# 3                         2                    0
# 59                        2                    0
# 30                        2                    0
# 9                         1                    0
# 33                        3                    0
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# gender                                      int64
# faculty                                    object
# ug_pg                                      object
# year                                        int64
# csp_cleared                                 int64
# cleared_mode                               object
# clearing_plan                              object
# freq_see_elderly                            int64
# elderly_do                                 object
# knowledge_elderly_pop                       int64
# freq_interact_w_elderly                     int64
# difficulties_interacting                    int64
# difficulties_face                          object
# interest_participate_elderly_center_csp     int64
# thoughts_inter_hub                          int64
# thoughts                                   object
# brand                                      object
# disrupt_student_lives                       int64
# disrupt_reason                             object
# interest_csp_elderly_smu                    int64
# csp_elderly_related                         int64
# dtype: object

# %%
df["csp_elderly_related"].sample(10)
# Out:
# 28    0
# 26    1
# 30    0
# 45    0
# 3     0
# 2     0
# 71    0
# 61    1
# 59    0
# 36    0
# Name: csp_elderly_related, dtype: int64

# %%
def categories_interest(data):
    if data == 4:
        return "Very High"
    if data == 3:
        return "High"
    if data == 2:
        return "Low"
    if data == 1:
        return "Very Low"

def categories_interaction_w_elderly(data):
    if data == 4:
        return "Very often"
    if data == 3:
        return "Often"
    if data == 2:
        return "Seldom"
    if data == 1:
        return "Not at All"

df["interest_csp_elderly_categorized"] = df["interest_csp_elderly_smu"].apply(categories_interest)
#df["interest_csp_elderly_categorized"]


df["interact_w_elderly_categorized"] = df["freq_interact_w_elderly"].apply(categories_interaction_w_elderly)
df["interact_w_elderly_categorized"]
# Out:
# 0     Very often
# 1     Not at All
# 2     Not at All
# 3     Not at All
# 4     Not at All
#          ...
# 69    Not at All
# 70    Not at All
# 71        Seldom
# 72        Seldom
# 73        Seldom
# Name: interact_w_elderly_categorized, Length: 74, dtype: object

# %%
plt.figure(figsize=(10,10))
with sns.plotting_context("notebook",font_scale=1.5):
    g =sns.countplot(df["interact_w_elderly_categorized"],order=["Not at All","Seldom","Often","Very often"],palette=smucolors)
g.set(xlabel="Frequency of Interacting with Elderly")
# Out:
# [Text(0.5,0,'Frequency of Interacting with Elderly')]

# %%
df["interest_csp_elderly_categorized"].value_counts(1)
# Out:
# High         0.405405
# Very High    0.243243
# Low          0.189189
# Very Low     0.162162
# Name: interest_csp_elderly_categorized, dtype: float64

# %%
sns.countplot(df["interest_csp_elderly_categorized"])

# %%
plt.figure(figsize=[5,40])

ax = sns.catplot(col_wrap= 2,x="interest_csp_elderly_categorized", kind="count", data=df,col="interact_w_elderly_categorized",col_order=["Not at All","Seldom","Often","Very often"],palette=smucolors)
plt.subplots_adjust(top=0.9)
ax.set_axis_labels("Frequency of Interacting with Elderly", "interact_w_elderly_categorized");
ax.set_axis_labels("Interest level for Elderly Related CSP", "interest_csp_elderly_categorized");
ax.fig.suptitle("Relationship of Interacting with Elderly vs Interest with Elderly CSP ")
# Out:
# Text(0.5,0.98,'Relationship of Interacting with Elderly vs Interest with Elderly CSP ')

# %%
print(df["interest_csp_elderly_categorized"].value_counts(1))
# Out:
# High         0.405405
# Very High    0.243243
# Low          0.189189
# Very Low     0.162162
# Name: interest_csp_elderly_categorized, dtype: float64

# %%
#Correlation of variables in the data
corr = df.corr()

ax = sns.heatmap(corr,vmin=-1,vmax=1,center=0,cmap=sns.diverging_palette(20,220,n=200),square=True)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
corr.round(5)
# Out:
#                                           gender     year  csp_cleared  \
# gender                                   1.00000  0.07519      0.13299
# year                                     0.07519  1.00000      0.60815
# csp_cleared                              0.13299  0.60815      1.00000
# freq_see_elderly                         0.04387  0.02031      0.09831
# knowledge_elderly_pop                    0.16729  0.12357      0.07770
# freq_interact_w_elderly                  0.08933 -0.07603      0.08948
# difficulties_interacting                 0.00968  0.03375     -0.09492
# interest_participate_elderly_center_csp -0.06358 -0.07162     -0.07104
# thoughts_inter_hub                      -0.14555 -0.04596      0.08062
# disrupt_student_lives                    0.09317 -0.09248     -0.07732
# interest_csp_elderly_smu                -0.09880  0.01221     -0.01762
# csp_elderly_related                      0.11694  0.22461      0.23066
#
#                                          freq_see_elderly  \
# gender                                            0.04387
# year                                              0.02031
# csp_cleared                                       0.09831
# freq_see_elderly                                  1.00000
# knowledge_elderly_pop                             0.01005
# freq_interact_w_elderly                           0.06683
# difficulties_interacting                          0.02903
# interest_participate_elderly_center_csp          -0.01322
# thoughts_inter_hub                                0.13200
# disrupt_student_lives                             0.04309
# interest_csp_elderly_smu                          0.02201
# csp_elderly_related                              -0.12173
#
#                                          knowledge_elderly_pop  \
# gender                                                 0.16729
# year                                                   0.12357
# csp_cleared                                            0.07770
# freq_see_elderly                                       0.01005
# knowledge_elderly_pop                                  1.00000
# freq_interact_w_elderly                               -0.10396
# difficulties_interacting                              -0.04542
# interest_participate_elderly_center_csp               -0.17832
# thoughts_inter_hub                                    -0.05479
# disrupt_student_lives                                 -0.03451
# interest_csp_elderly_smu                              -0.09880
# csp_elderly_related                                   -0.09310
#
#                                          freq_interact_w_elderly  \
# gender                                                   0.08933
# year                                                    -0.07603
# csp_cleared                                              0.08948
# freq_see_elderly                                         0.06683
# knowledge_elderly_pop                                   -0.10396
# freq_interact_w_elderly                                  1.00000
# difficulties_interacting                                 0.03993
# interest_participate_elderly_center_csp                  0.26023
# thoughts_inter_hub                                       0.21808
# disrupt_student_lives                                   -0.01922
# interest_csp_elderly_smu                                 0.03235
# csp_elderly_related                                      0.00079
#
#                                          difficulties_interacting  \
# gender                                                    0.00968
# year                                                      0.03375
# csp_cleared                                              -0.09492
# freq_see_elderly                                          0.02903
# knowledge_elderly_pop                                    -0.04542
# freq_interact_w_elderly                                   0.03993
# difficulties_interacting                                  1.00000
# interest_participate_elderly_center_csp                  -0.08003
# thoughts_inter_hub                                       -0.01623
# disrupt_student_lives                                    -0.06508
# interest_csp_elderly_smu                                 -0.05635
# csp_elderly_related                                       0.04958
#
#                                          interest_participate_elderly_center_csp  \
# gender                                                                  -0.06358
# year                                                                    -0.07162
# csp_cleared                                                             -0.07104
# freq_see_elderly                                                        -0.01322
# knowledge_elderly_pop                                                   -0.17832
# freq_interact_w_elderly                                                  0.26023
# difficulties_interacting                                                -0.08003
# interest_participate_elderly_center_csp                                  1.00000
# thoughts_inter_hub                                                       0.45296
# disrupt_student_lives                                                   -0.24251
# interest_csp_elderly_smu                                                 0.45034
# csp_elderly_related                                                      0.03168
#
#                                          thoughts_inter_hub  \
# gender                                             -0.14555
# year                                               -0.04596
# csp_cleared                                         0.08062
# freq_see_elderly                                    0.13200
# knowledge_elderly_pop                              -0.05479
# freq_interact_w_elderly                             0.21808
# difficulties_interacting                           -0.01623
# interest_participate_elderly_center_csp             0.45296
# thoughts_inter_hub                                  1.00000
# disrupt_student_lives                              -0.22850
# interest_csp_elderly_smu                            0.40584
# csp_elderly_related                                 0.09096
#
#                                          disrupt_student_lives  \
# gender                                                 0.09317
# year                                                  -0.09248
# csp_cleared                                           -0.07732
# freq_see_elderly                                       0.04309
# knowledge_elderly_pop                                 -0.03451
# freq_interact_w_elderly                               -0.01922
# difficulties_interacting                              -0.06508
# interest_participate_elderly_center_csp               -0.24251
# thoughts_inter_hub                                    -0.22850
# disrupt_student_lives                                  1.00000
# interest_csp_elderly_smu                              -0.22384
# csp_elderly_related                                   -0.06528
#
#                                          interest_csp_elderly_smu  \
# gender                                                   -0.09880
# year                                                      0.01221
# csp_cleared                                              -0.01762
# freq_see_elderly                                          0.02201
# knowledge_elderly_pop                                    -0.09880
# freq_interact_w_elderly                                   0.03235
# difficulties_interacting                                 -0.05635
# interest_participate_elderly_center_csp                   0.45034
# thoughts_inter_hub                                        0.40584
# disrupt_student_lives                                    -0.22384
# interest_csp_elderly_smu                                  1.00000
# csp_elderly_related                                       0.14338
#
#                                          csp_elderly_related
# gender                                               0.11694
# year                                                 0.22461
# csp_cleared                                          0.23066
# freq_see_elderly                                    -0.12173
# knowledge_elderly_pop                               -0.09310
# freq_interact_w_elderly                              0.00079
# difficulties_interacting                             0.04958
# interest_participate_elderly_center_csp              0.03168
# thoughts_inter_hub                                   0.09096
# disrupt_student_lives                               -0.06528
# interest_csp_elderly_smu                             0.14338
# csp_elderly_related                                  1.00000

# %%
students_w_difficulty_interacting = df.loc[df["difficulties_interacting"]==1]

students_w_difficulty_interacting["freq_interact_w_elderly"].value_counts(1)
# Out:
# 2    0.484848
# 1    0.424242
# 3    0.090909
# Name: freq_interact_w_elderly, dtype: float64

# %%
df["freq_interact_w_elderly"].head(15)
# Out:
# 0     4
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     4
# 7     2
# 8     2
# 9     1
# 10    1
# 11    1
# 12    2
# 13    1
# 14    1
# Name: freq_interact_w_elderly, dtype: int64

# %%
x_cols = ["gender","freq_see_elderly","knowledge_elderly_pop","freq_interact_w_elderly","difficulties_interacting","disrupt_student_lives","thoughts_inter_hub"]
y_col = "interest_csp_elderly_smu"

series = []

for col in x_cols:
    series.append(df[col])

x_df = pd.concat(series,axis=1)
x_df.head(20)
# Out:
#     gender  freq_see_elderly  knowledge_elderly_pop  freq_interact_w_elderly  \
# 0        0                 1                      0                        4
# 1        0                 2                      0                        1
# 2        0                 1                      0                        1
# 3        0                 1                      1                        1
# 4        0                 3                      0                        1
# 5        0                 1                      0                        1
# 6        1                 3                      0                        4
# 7        1                 1                      0                        2
# 8        1                 2                      1                        2
# 9        1                 2                      0                        1
# 10       1                 3                      1                        1
# 11       0                 2                      1                        1
# 12       0                 2                      1                        2
# 13       1                 2                      0                        1
# 14       0                 3                      0                        1
# 15       0                 2                      1                        2
# 16       1                 3                      0                        2
# 17       0                 4                      0                        2
# 18       0                 3                      1                        1
# 19       1                 3                      1                        2
#
#     difficulties_interacting  disrupt_student_lives  thoughts_inter_hub
# 0                          0                      0                   3
# 1                          0                      0                   1
# 2                          0                      0                   3
# 3                          0                      0                   3
# 4                          0                      0                   4
# 5                          0                      1                   2
# 6                          0                      1                   3
# 7                          0                      0                   3
# 8                          0                      0                   4
# 9                          1                      1                   1
# 10                         0                      0                   2
# 11                         1                      0                   2
# 12                         1                      0                   4
# 13                         0                      1                   1
# 14                         0                      1                   3
# 15                         0                      1                   4
# 16                         0                      0                   4
# 17                         0                      1                   4
# 18                         1                      1                   2
# 19                         1                      0                   3

# %%
#If user indicates 3 or more it means they are keen to explore elderly related CSP in SMU
def prep_class_labels(data):
    if data >= 3:
        return 1
    else:
        return 0

    
x_data = x_df
prepped_y = df[y_col].apply(prep_class_labels)
y_data = prepped_y

# %%
values = x_df["disrupt_student_lives"].value_counts()

print(values)

labels = 'No','Yes'
sizes = [values[0],values[1]]
explode = (0.15,0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# 0    56
# 1    18
# Name: disrupt_student_lives, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from wordcloud import WordCloud
from nltk import bigrams
from nltk import trigrams

difficulties_face_text = df["difficulties_face"]

# %%
content = ""

for row in difficulties_face_text:
    content += row + " "
    

tokenizer = RegexpTokenizer(r'\w+')
words = tokenizer.tokenize(content)


stop_words = stopwords.words('english')
len(words)
# Out:
# 252

# %%
words_filtered = []

for w in words:
    w = w.lower()
    w = w.strip()
    if w not in stop_words:
        words_filtered.append(w)
        
len(words_filtered)

  
lemmatizer = WordNetLemmatizer()
words_filtered_stemmed = []

for w in words_filtered:
    words_filtered_stemmed.append(lemmatizer.lemmatize(w))

# %%
words_joined = " ".join([w for w in words_filtered_stemmed])
# Create a word cloud
my_wordcloud = WordCloud(background_color='white',
                         width=1500,
                         height=800).generate(words_joined)

plt.figure( figsize=(20,10))
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()

# %%
n_grams_filtered_words  = []

n_grams_stop = ["im","at","that","will","which","there","i", "think","as","don","it","or",
                "have","to","be","the","is","an","are","they","were","if","and"]

for w in words:
    w = w.lower()
    w = w.strip()
    

    if w not in n_grams_stop:
        n_grams_filtered_words.append(w)
        
n_grams_filtered_words_lemmatized = []
for w in n_grams_filtered_words:
    n_grams_filtered_words_lemmatized.append(lemmatizer.lemmatize(w,'v'))

# %%
bigrams_words = bigrams(n_grams_filtered_words_lemmatized)

bigrm_tup_list = list(bigrams_words)
bigram_list = []

for tup in bigrm_tup_list:
    content = ""
    for item in tup:
        content += item + "_"
    bigram_list.append(content)

bi_words_joined = " ".join([w for w in bigram_list])

# %%
my_wordcloud_bi = WordCloud(background_color='white',
                         width=1500,
                         height=800).generate(bi_words_joined)

plt.figure( figsize=(20,10))
plt.imshow(my_wordcloud_bi)
plt.axis('off')
plt.show()
